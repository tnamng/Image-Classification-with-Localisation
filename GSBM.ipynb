# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Mounted at gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/AI/Kaggle"

# %%
# !kaggle datasets download -d meowmeowmeowmeowmeow/gtsrb-german-traffic-sign
# !unzip gtsrb-german-traffic-sign.zip

# %%
# Download and unpack the training set and the test set

#!wget https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Training_Images.zip 
#!wget https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Test_Images.zip 
# !wget https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Test_GT.zip 

#!unzip GTSRB_Final_Training_Images.zip 
#!unzip GTSRB_Final_Test_Images.zip 
# !unzip GTSRB_Final_Test_GT.zip 
# Move the test set to data/test
# Out:
# --2021-02-23 14:13:04--  https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Test_GT.zip
# Resolving sid.erda.dk (sid.erda.dk)... 130.225.104.13
# Connecting to sid.erda.dk (sid.erda.dk)|130.225.104.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99620 (97K) [application/zip]
# Saving to: ‘GTSRB_Final_Test_GT.zip’
#
# GTSRB_Final_Test_GT 100%[===================>]  97.29K   312KB/s    in 0.3s
#
# 2021-02-23 14:13:05 (312 KB/s) - ‘GTSRB_Final_Test_GT.zip’ saved [99620/99620]
#
# Archive:  GTSRB_Final_Test_GT.zip
# replace GT-final_test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: GT-final_test.csv

# %%
! mkdir data/test
! mv data/GTSRB/Final_Test/Images/*.ppm data/test

# Download class names
! wget https://raw.githubusercontent.com/georgesung/traffic_sign_classification_german/master/signnames.csv -P data

# %%
import tensorflow as tf

# %%
url_data = "https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Training_Images.zip"
# Out:
# --2021-02-23 13:42:30--  http://url_data/
# Resolving url_data (url_data)... failed: Name or service not known.
# wget: unable to resolve host address ‘url_data’

# %%
train_file = tf.keras.utils.get_file(
            origin=url_data,
            fname="GTSRB_Final_Training_Images.zip",
            extract=True
        )
# Out:
# Downloading data from https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Training_Images.zip
# 276299776/276294756 [==============================] - 11s 0us/step
