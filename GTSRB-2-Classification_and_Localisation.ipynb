# %% [markdown]
# # Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


import random

### Các thư viện I/O, File
import os
import glob
import shutil
import zipfile
### Các thư viện hình ảnh (bổ sung)
from PIL import Image, ImageDraw
import matplotlib.image as mpimg 

###################################################
from sklearn.model_selection import train_test_split
###################################################
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# %% [markdown]
# # Download data and EDA

# %%
#####******FOR COLAB DOWLOAD DATASETS*****#########
GTSRB_DATA_URL = "https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Training_Images.zip"
tf.keras.utils.get_file(
    fname = 'GTSRB_Final_Training_Images.zip', 
    origin = GTSRB_DATA_URL, 
    cache_subdir='datasets', 
    extract=True
)
DOWNLOAD_PATH = "/root/.keras/datasets/"
GTSRB_DATA_PATH = os.path.join(DOWNLOAD_PATH,  "GTSRB/Final_Training/Images")
# Out:
# Downloading data from https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/GTSRB_Final_Training_Images.zip
# 276299776/276294756 [==============================] - 17s 0us/step

# %%
# DOWNLOAD_PATH = "/Users/macintosh/Desktop"
# GTSRB_DATA_PATH = os.path.join(DOWNLOAD_PATH,  "GTSRB/Final_Training/Images")

# %%
N_CLASSES = 43
RESIZED_HIGHT = RESIZED_WIDTH = 32
RESIZED_IMAGE = (RESIZED_HIGHT, RESIZED_WIDTH)

# %% [markdown]
# ## Load and check all labes

# %%
def load_labels_from_one_directory(SOURCE, i):
    dir_name = format(i, '05d')
    dir_path = os.path.join(SOURCE, dir_name)
    filename = 'GT-' + dir_name + '.csv'
    file_path = os.path.join(dir_path, filename)
    df = pd.read_csv(file_path, delimiter=";")
    df['File_path'] = df['Filename'].map(lambda x: os.path.join(dir_path, x))
    df.drop('Filename', axis = 1, inplace = True)
    return df

def load_all_labels(SOURCE):
    list_label_df = []
    for i in range(N_CLASSES):
        df = load_labels_from_one_directory(SOURCE, i)
        list_label_df.append(df)
    return pd.concat(list_label_df, axis = 0, ignore_index=True)

df = load_all_labels(GTSRB_DATA_PATH)

# %%
df.head()
# Out:
#    Width  Height  ...  ClassId                                          File_path
# 0     29      30  ...        0  /root/.keras/datasets/GTSRB/Final_Training/Ima...
# 1     30      30  ...        0  /root/.keras/datasets/GTSRB/Final_Training/Ima...
# 2     30      30  ...        0  /root/.keras/datasets/GTSRB/Final_Training/Ima...
# 3     31      31  ...        0  /root/.keras/datasets/GTSRB/Final_Training/Ima...
# 4     30      32  ...        0  /root/.keras/datasets/GTSRB/Final_Training/Ima...
#
# [5 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39209 entries, 0 to 39208
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Width      39209 non-null  int64
#  1   Height     39209 non-null  int64
#  2   Roi.X1     39209 non-null  int64
#  3   Roi.Y1     39209 non-null  int64
#  4   Roi.X2     39209 non-null  int64
#  5   Roi.Y2     39209 non-null  int64
#  6   ClassId    39209 non-null  int64
#  7   File_path  39209 non-null  object
# dtypes: int64(7), object(1)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#               Width        Height  ...        Roi.Y2       ClassId
# count  39209.000000  39209.000000  ...  39209.000000  39209.000000
# mean      50.835880     50.328930  ...     44.728379     15.788390
# std       24.306933     23.115423  ...     21.971145     12.013238
# min       25.000000     25.000000  ...     20.000000      0.000000
# 25%       35.000000     35.000000  ...     30.000000      5.000000
# 50%       43.000000     43.000000  ...     38.000000     12.000000
# 75%       58.000000     58.000000  ...     52.000000     25.000000
# max      243.000000    225.000000  ...    205.000000     42.000000
#
# [8 rows x 7 columns]

# %%
sns.catplot(x = 'ClassId', data = df, kind = 'count');

# %%
sns.relplot(x = 'Width', y = 'Height', data = df, hue = 'ClassId')

# %%
sns.displot( x = "Width", data = df, kind="hist")

# %%
sns.displot( x = "Height", data = df, kind="hist")

# %%
# To check the relation between the boxes and the correpoding img size
check_number = min((df['Height'] - df['Roi.Y1']).min(),  
                       (df['Roi.Y2'] - df['Roi.Y1']).min(),
                       (df["Width"] - df['Roi.X1']).min(),
                       (df['Roi.X2'] - df['Roi.X1']).min())
    
if check_number>=0:
    print("All boxes fit  their correpoding img size") 
else:
    print("Have a probem between boxes and img size")
# Out:
# All boxes fit  their correpoding img size

# %% [markdown]
# ## View some images with their class and box (randomly)

# %%
def show_an_image_with_box(df, j):  
    img_path = df.loc[j]["File_path"]
    with Image.open(img_path) as img:
        box = list(df.loc[j]["Roi.X1":"Roi.Y2"])
        draw = ImageDraw.Draw(img)
        draw.rectangle(box, outline="green", width=1)
        plt.title('class: ' + str(df.loc[j]['ClassId']))
        plt.imshow(img)

# %%
all_img_paths = df["File_path"]
all_idxs = df.index
#choose some random number
nrows = 1 
ncols = 3
rand_Ids=np.random.choice(all_idxs,nrows*ncols)

len(all_idxs)

fig = plt.gcf() 
fig.set_size_inches(14,20)
for i, id_ in enumerate(rand_Ids):
    plt.subplot(nrows, ncols, i+1) 
    show_an_image_with_box(df, id_)

# %% [markdown]
# ## Load all images in the resized shape

# %%
def load_all_images(img_paths = []):
    list_img = []
    for img_path in img_paths:
        #with Image.open(img_path) as img      
        img = tf.keras.preprocessing.image.load_img(img_path, target_size = RESIZED_IMAGE)# Problem: do not close the file
        img = tf.keras.preprocessing.image.img_to_array(img)
        list_img.append(img)
    return  np.array(list_img)
img_paths = list(df["File_path"])
imgs = load_all_images(img_paths)

# %%
# def update_box():
#     df['resized_Roi.X1']  =  df['Roi.X1'] * RESIZED_WIDTH / df['Width']
#     df['resized_Roi.X2']  =  df['Roi.X2'] * RESIZED_WIDTH / df['Width']
#     df['resized_Roi.Y1']  =  df['Roi.Y1'] * RESIZED_HIGHT / df['Height']
#     df['resized_Roi.X2']  =  df['Roi.Y2'] * RESIZED_HIGHT / df['Height']
# update_box()

# %%
def add_rate_coordinates_box():
    """Using for the target"""
    df['rate_y_min'] = df['Roi.Y1'] /df.Height
    df['rate_x_min'] = df['Roi.X1'] /df.Width
    df['rate_y_max'] = df['Roi.Y2'] /df.Height
    df['rate_x_max'] = df['Roi.X2'] /df.Width
add_rate_coordinates_box()

# %%
def plot_image_with_box(img, box):
    """by using tf"""
    colors = np.array([[255,0,0]]) #red colors
    #img_arr = np.asarray(resized_img)
    img_arr = np.expand_dims(img, axis =0)
    
    box = box.reshape([1, 1, 4])
    
    new_img = tf.image.draw_bounding_boxes(img_arr, box, colors)
    plt.imshow(new_img[0]/255.0)
    plt.title('Resized image with box')
    plt.show()

# %%
# show image before and after resize
all_idxs = df.index
rand_Id=np.random.choice(all_idxs)
print('Randonm index = ', rand_Id)


fig = plt.figure()
plt.subplot(1, 2, 1) 
show_an_image_with_box(df, rand_Id)
plt.subplot(1, 2, 2)
box = np.array(df.loc[rand_Id]['rate_y_min':'rate_x_max'])
plot_image_with_box(imgs[rand_Id], box)
# Out:
# Randonm index =  67

# %% [markdown]
# # Creat train and test sets

# %% [markdown]
# ## Train/Split data and Transformation function

# %%
#Creat split data
from sklearn.model_selection import train_test_split

y = df[["ClassId"]].values
id_train, id_test, y_train, y_test = train_test_split(range(df.shape[0]), y, shuffle = True,
                                                            stratify = y, 
                                                      train_size = 0.8, random_state = 42)
X_train = imgs[id_train]
X_test = imgs[id_test] 

target_boxes_train = df.loc[id_train, 'rate_y_min':'rate_x_max'].values
target_boxes_test = df.loc[id_test,'rate_y_min':'rate_x_max'].values

# %%
X_train.shape, X_test.shape, y_train.shape,  y_test.shape
# Out:
# ((31367, 32, 32, 3), (7842, 32, 32, 3), (31367, 1), (7842, 1))

# %%
target_boxes_train.shape, target_boxes_test.shape
# Out:
# ((31367, 4), (7842, 4))

# %%
#TRANSFORMATION FUNCTION
def transform(img, b, c, is_training = True):
    #a = tf.cast(a/255, tf.float32)
    #b = tf.cast(b, tf.float32)
    #c = tf.cast(c, tf.float32)
    rand = tf.random.uniform([1])
    if is_training and (rand >0.5):
        img = tf.image.random_brightness(img, max_delta = 0.95)
    return img/255, (b, c)

# %% [markdown]
# ## Make  a tf.data Data with transformation

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE  #Version 2.0
##AUTOTUNE = tf.data.AUTOTUNE  #Version 2.xx

def creat_dataset(X, y, target_boxes, batch_size, is_training = True):  #batch_size,
    ds = tf.data.Dataset.from_tensor_slices((X, y, target_boxes))  # Tạo một LIST các cặp X_i, y_i
    ds = ds.map(lambda a, b, c: transform(a, b, c, is_training))  #, num_parallel_calls = AUTOTUNE
    #dataset.map(time_consuming_mapping).cache().map(memory_consuming_mapping)
    if is_training:
        m = target_boxes.shape[0]
        shuffle_buffer = m              
        ds = ds.shuffle(shuffle_buffer)
    #ds = ds.repeat() # Mandatory for Keras for now
    ds = ds.batch(batch_size, drop_remainder = True).prefetch(1)   # Thêm chiều cho trục axis = 0 cho list bên trên 
    return ds

# %%
BATCH_SIZE = 64
ds_train = creat_dataset(X_train, y_train, target_boxes_train, BATCH_SIZE)
ds_test = creat_dataset(X_test, y_test, target_boxes_test, BATCH_SIZE//2, is_training = False)

# %%
ds_train.element_spec
# Out:
# (TensorSpec(shape=(64, 32, 32, 3), dtype=tf.float32, name=None),
#  (TensorSpec(shape=(64, 1), dtype=tf.int64, name=None),
#   TensorSpec(shape=(64, 4), dtype=tf.float64, name=None)))

# %%
ds_train.element_spec
# Out:
# (TensorSpec(shape=(64, 32, 32, 3), dtype=tf.float32, name=None),
#  (TensorSpec(shape=(64, 1), dtype=tf.int64, name=None),
#   TensorSpec(shape=(64, 4), dtype=tf.float64, name=None)))

# %%
# import multiprocessing
# cores = multiprocessing.cpu_count()
# ## num_parallel_calls= cores ##
# print(cores)

# %% [markdown]
# # Model

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Input, Lambda 
from tensorflow.keras.models import Model
from tensorflow.python.keras.utils.vis_utils import plot_model

# %% [markdown]
# ## Architecture

# %% [markdown]
# ### Pipeline layers

# %%
@tf.function
def my_pipeline_function(img):
    if tf.math.reduce_mean(img) < 0.3 :
        img = tf.image.adjust_contrast(img, 5)
        img = tf.image.adjust_brightness(img, 0.2)
    return img

def my_pipeline_layers():
    return Lambda(lambda input_layer: my_pipeline_function(input_layer))

# %% [markdown]
# ### Buid model

# %%
def build_model():
    input_layer = Input(shape=(RESIZED_HIGHT, RESIZED_WIDTH, 3))
    x = my_pipeline_layers()(input_layer)
    Conv2D(32, (5,5), activation = 'relu')(x)
    Conv2D(64, (5,5), activation = 'relu')(x)
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    #x = Dropout(0.4)(x)
    clf_output = Dense(N_CLASSES, activation='softmax', name = 'ouput_clf')(x)
    box_output = Dense(4, name = 'ouput_reg')(x)
    model = Model(inputs = input_layer, outputs = [clf_output, box_output])
    return model
model = build_model()

# %%
model.summary()
plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 32, 32, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3072)         0           lambda[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         3146752     flatten[0][0]
# __________________________________________________________________________________________________
# ouput_clf (Dense)               (None, 43)           44075       dense[0][0]
# __________________________________________________________________________________________________
# ouput_reg (Dense)               (None, 4)            4100        dense[0][0]
# ==================================================================================================
# Total params: 3,194,927
# Trainable params: 3,194,927
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Optimization

# %%
# def intersection_over_union(pred_box, true_box):
#     xmin_pred, ymin_pred, xmax_pred, ymax_pred =  tf.split(pred_box, 4, axis = 0)
#     xmin_true, ymin_true, xmax_true, ymax_true = tf.split(true_box, 4, axis = 0)


#     xmin_overlap = tf.math.maximum(xmin_pred, xmin_true)
#     xmax_overlap = tf.math.minimum(xmax_pred, xmax_true)
#     ymin_overlap = tf.math.maximum(xmin_pred, xmin_true)
#     ymax_overlap = tf.math.minimum(ymax_pred, ymax_true)

#     pred_box_area = (xmax_pred - xmin_pred ) * (ymax_pred - ymin_pred )
#     true_box_area = (xmax_true - xmin_true) * (ymax_true - ymin_true)

#     overlap_area = tf.math.maximum((xmax_overlap - xmin_overlap), 0)  * tf.math.maximum((ymax_overlap - ymin_overlap), 0)
#     union_area = (pred_box_area + true_box_area) - overlap_area

#     iou = overlap_area / union_area

#     return iou

# %%
    #model.compile(loss=["mse", "mse"], , optimizer="sgd")
    model.compile(optimizer='adam',
                  loss=['sparse_categorical_crossentropy', 'mse'],
                  #loss_weights=[0.5, 0.5],
                  metrics= ['accuracy', 'mse'])

# %% [markdown]
# # Training process

# %%
history = model.fit(ds_train, 
          validation_data=ds_test,
          epochs=30)
# Out:
# Epoch 1/30
# 490/490 [==============================] - 7s 7ms/step - loss: 4.2526 - ouput_clf_loss: 2.8920 - ouput_reg_loss: 1.3606 - ouput_clf_accuracy: 0.2942 - ouput_clf_mse: 392.1467 - ouput_reg_accuracy: 0.4817 - ouput_reg_mse: 1.3606 - val_loss: 1.4771 - val_ouput_clf_loss: 1.4090 - val_ouput_reg_loss: 0.0681 - val_ouput_clf_accuracy: 0.6573 - val_ouput_clf_mse: 392.9542 - val_ouput_reg_accuracy: 0.4533 - val_ouput_reg_mse: 0.0681
# Epoch 2/30
# 490/490 [==============================] - 4s 6ms/step - loss: 1.3009 - ouput_clf_loss: 1.2407 - ouput_reg_loss: 0.0602 - ouput_clf_accuracy: 0.7149 - ouput_clf_mse: 393.1869 - ouput_reg_accuracy: 0.5349 - ouput_reg_mse: 0.0602 - val_loss: 0.8877 - val_ouput_clf_loss: 0.8522 - val_ouput_reg_loss: 0.0355 - val_ouput_clf_accuracy: 0.8059 - val_ouput_clf_mse: 392.9583 - val_ouput_reg_accuracy: 0.5439 - val_ouput_reg_mse: 0.0355
# Epoch 3/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.8560 - ouput_clf_loss: 0.8246 - ouput_reg_loss: 0.0314 - ouput_clf_accuracy: 0.8104 - ouput_clf_mse: 390.9936 - ouput_reg_accuracy: 0.5344 - ouput_reg_mse: 0.0314 - val_loss: 0.7285 - val_ouput_clf_loss: 0.6986 - val_ouput_reg_loss: 0.0299 - val_ouput_clf_accuracy: 0.8360 - val_ouput_clf_mse: 392.9601 - val_ouput_reg_accuracy: 0.5853 - val_ouput_reg_mse: 0.0299
# Epoch 4/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.6713 - ouput_clf_loss: 0.6420 - ouput_reg_loss: 0.0293 - ouput_clf_accuracy: 0.8520 - ouput_clf_mse: 394.7714 - ouput_reg_accuracy: 0.5352 - ouput_reg_mse: 0.0293 - val_loss: 0.6201 - val_ouput_clf_loss: 0.6011 - val_ouput_reg_loss: 0.0189 - val_ouput_clf_accuracy: 0.8592 - val_ouput_clf_mse: 392.9619 - val_ouput_reg_accuracy: 0.5092 - val_ouput_reg_mse: 0.0189
# Epoch 5/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.5551 - ouput_clf_loss: 0.5360 - ouput_reg_loss: 0.0191 - ouput_clf_accuracy: 0.8725 - ouput_clf_mse: 390.7779 - ouput_reg_accuracy: 0.5258 - ouput_reg_mse: 0.0191 - val_loss: 0.6543 - val_ouput_clf_loss: 0.6326 - val_ouput_reg_loss: 0.0217 - val_ouput_clf_accuracy: 0.8353 - val_ouput_clf_mse: 392.9626 - val_ouput_reg_accuracy: 0.5654 - val_ouput_reg_mse: 0.0217
# Epoch 6/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.4868 - ouput_clf_loss: 0.4713 - ouput_reg_loss: 0.0156 - ouput_clf_accuracy: 0.8884 - ouput_clf_mse: 391.6500 - ouput_reg_accuracy: 0.5409 - ouput_reg_mse: 0.0156 - val_loss: 0.5221 - val_ouput_clf_loss: 0.5118 - val_ouput_reg_loss: 0.0103 - val_ouput_clf_accuracy: 0.8837 - val_ouput_clf_mse: 392.9634 - val_ouput_reg_accuracy: 0.5750 - val_ouput_reg_mse: 0.0103
# Epoch 7/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.4228 - ouput_clf_loss: 0.4122 - ouput_reg_loss: 0.0107 - ouput_clf_accuracy: 0.8994 - ouput_clf_mse: 386.3838 - ouput_reg_accuracy: 0.5409 - ouput_reg_mse: 0.0107 - val_loss: 0.4879 - val_ouput_clf_loss: 0.4755 - val_ouput_reg_loss: 0.0124 - val_ouput_clf_accuracy: 0.8920 - val_ouput_clf_mse: 392.9640 - val_ouput_reg_accuracy: 0.5629 - val_ouput_reg_mse: 0.0124
# Epoch 8/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.4238 - ouput_clf_loss: 0.3815 - ouput_reg_loss: 0.0423 - ouput_clf_accuracy: 0.9113 - ouput_clf_mse: 395.6169 - ouput_reg_accuracy: 0.5171 - ouput_reg_mse: 0.0423 - val_loss: 0.4793 - val_ouput_clf_loss: 0.4747 - val_ouput_reg_loss: 0.0046 - val_ouput_clf_accuracy: 0.8953 - val_ouput_clf_mse: 392.9644 - val_ouput_reg_accuracy: 0.5538 - val_ouput_reg_mse: 0.0046
# Epoch 9/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.3546 - ouput_clf_loss: 0.3473 - ouput_reg_loss: 0.0074 - ouput_clf_accuracy: 0.9187 - ouput_clf_mse: 389.9884 - ouput_reg_accuracy: 0.5288 - ouput_reg_mse: 0.0074 - val_loss: 0.4577 - val_ouput_clf_loss: 0.4506 - val_ouput_reg_loss: 0.0071 - val_ouput_clf_accuracy: 0.9013 - val_ouput_clf_mse: 392.9646 - val_ouput_reg_accuracy: 0.5327 - val_ouput_reg_mse: 0.0071
# Epoch 10/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.3277 - ouput_clf_loss: 0.3208 - ouput_reg_loss: 0.0069 - ouput_clf_accuracy: 0.9219 - ouput_clf_mse: 393.8521 - ouput_reg_accuracy: 0.5402 - ouput_reg_mse: 0.0069 - val_loss: 0.5232 - val_ouput_clf_loss: 0.4598 - val_ouput_reg_loss: 0.0634 - val_ouput_clf_accuracy: 0.8985 - val_ouput_clf_mse: 392.9649 - val_ouput_reg_accuracy: 0.6130 - val_ouput_reg_mse: 0.0634
# Epoch 11/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.3535 - ouput_clf_loss: 0.3154 - ouput_reg_loss: 0.0381 - ouput_clf_accuracy: 0.9234 - ouput_clf_mse: 392.0305 - ouput_reg_accuracy: 0.5269 - ouput_reg_mse: 0.0381 - val_loss: 0.3910 - val_ouput_clf_loss: 0.3889 - val_ouput_reg_loss: 0.0021 - val_ouput_clf_accuracy: 0.9235 - val_ouput_clf_mse: 392.9653 - val_ouput_reg_accuracy: 0.4865 - val_ouput_reg_mse: 0.0021
# Epoch 12/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.2702 - ouput_clf_loss: 0.2617 - ouput_reg_loss: 0.0085 - ouput_clf_accuracy: 0.9375 - ouput_clf_mse: 398.5399 - ouput_reg_accuracy: 0.5095 - ouput_reg_mse: 0.0085 - val_loss: 0.4041 - val_ouput_clf_loss: 0.3933 - val_ouput_reg_loss: 0.0108 - val_ouput_clf_accuracy: 0.9240 - val_ouput_clf_mse: 392.9653 - val_ouput_reg_accuracy: 0.4675 - val_ouput_reg_mse: 0.0108
# Epoch 13/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.2654 - ouput_clf_loss: 0.2478 - ouput_reg_loss: 0.0176 - ouput_clf_accuracy: 0.9394 - ouput_clf_mse: 397.3013 - ouput_reg_accuracy: 0.5222 - ouput_reg_mse: 0.0176 - val_loss: 0.4775 - val_ouput_clf_loss: 0.4762 - val_ouput_reg_loss: 0.0013 - val_ouput_clf_accuracy: 0.8964 - val_ouput_clf_mse: 392.9653 - val_ouput_reg_accuracy: 0.5041 - val_ouput_reg_mse: 0.0013
# Epoch 14/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.2845 - ouput_clf_loss: 0.2827 - ouput_reg_loss: 0.0018 - ouput_clf_accuracy: 0.9309 - ouput_clf_mse: 395.6674 - ouput_reg_accuracy: 0.5380 - ouput_reg_mse: 0.0018 - val_loss: 0.3979 - val_ouput_clf_loss: 0.3802 - val_ouput_reg_loss: 0.0176 - val_ouput_clf_accuracy: 0.9237 - val_ouput_clf_mse: 392.9656 - val_ouput_reg_accuracy: 0.6082 - val_ouput_reg_mse: 0.0176
# Epoch 15/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.2393 - ouput_clf_loss: 0.2281 - ouput_reg_loss: 0.0111 - ouput_clf_accuracy: 0.9442 - ouput_clf_mse: 396.1990 - ouput_reg_accuracy: 0.5036 - ouput_reg_mse: 0.0111 - val_loss: 0.4032 - val_ouput_clf_loss: 0.4016 - val_ouput_reg_loss: 0.0016 - val_ouput_clf_accuracy: 0.9230 - val_ouput_clf_mse: 392.9657 - val_ouput_reg_accuracy: 0.5536 - val_ouput_reg_mse: 0.0016
# Epoch 16/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.3513 - ouput_clf_loss: 0.2773 - ouput_reg_loss: 0.0740 - ouput_clf_accuracy: 0.9322 - ouput_clf_mse: 396.1504 - ouput_reg_accuracy: 0.5183 - ouput_reg_mse: 0.0740 - val_loss: 0.4282 - val_ouput_clf_loss: 0.4255 - val_ouput_reg_loss: 0.0028 - val_ouput_clf_accuracy: 0.9151 - val_ouput_clf_mse: 392.9657 - val_ouput_reg_accuracy: 0.3983 - val_ouput_reg_mse: 0.0028
# Epoch 17/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.2279 - ouput_clf_loss: 0.2259 - ouput_reg_loss: 0.0020 - ouput_clf_accuracy: 0.9441 - ouput_clf_mse: 394.0426 - ouput_reg_accuracy: 0.4961 - ouput_reg_mse: 0.0020 - val_loss: 0.3381 - val_ouput_clf_loss: 0.3367 - val_ouput_reg_loss: 0.0014 - val_ouput_clf_accuracy: 0.9307 - val_ouput_clf_mse: 392.9659 - val_ouput_reg_accuracy: 0.5079 - val_ouput_reg_mse: 0.0014
# Epoch 18/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.2105 - ouput_clf_loss: 0.2043 - ouput_reg_loss: 0.0062 - ouput_clf_accuracy: 0.9505 - ouput_clf_mse: 390.2335 - ouput_reg_accuracy: 0.5033 - ouput_reg_mse: 0.0062 - val_loss: 0.4710 - val_ouput_clf_loss: 0.4552 - val_ouput_reg_loss: 0.0157 - val_ouput_clf_accuracy: 0.9027 - val_ouput_clf_mse: 392.9655 - val_ouput_reg_accuracy: 0.3622 - val_ouput_reg_mse: 0.0157
# Epoch 19/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.2126 - ouput_clf_loss: 0.2064 - ouput_reg_loss: 0.0062 - ouput_clf_accuracy: 0.9470 - ouput_clf_mse: 390.4099 - ouput_reg_accuracy: 0.5094 - ouput_reg_mse: 0.0062 - val_loss: 0.3588 - val_ouput_clf_loss: 0.3567 - val_ouput_reg_loss: 0.0021 - val_ouput_clf_accuracy: 0.9333 - val_ouput_clf_mse: 392.9660 - val_ouput_reg_accuracy: 0.4597 - val_ouput_reg_mse: 0.0021
# Epoch 20/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.1837 - ouput_clf_loss: 0.1732 - ouput_reg_loss: 0.0105 - ouput_clf_accuracy: 0.9598 - ouput_clf_mse: 393.8729 - ouput_reg_accuracy: 0.5153 - ouput_reg_mse: 0.0105 - val_loss: 0.3750 - val_ouput_clf_loss: 0.3333 - val_ouput_reg_loss: 0.0418 - val_ouput_clf_accuracy: 0.9392 - val_ouput_clf_mse: 392.9661 - val_ouput_reg_accuracy: 0.5193 - val_ouput_reg_mse: 0.0418
# Epoch 21/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.2037 - ouput_clf_loss: 0.1691 - ouput_reg_loss: 0.0346 - ouput_clf_accuracy: 0.9588 - ouput_clf_mse: 390.8227 - ouput_reg_accuracy: 0.4908 - ouput_reg_mse: 0.0346 - val_loss: 0.5359 - val_ouput_clf_loss: 0.3882 - val_ouput_reg_loss: 0.1477 - val_ouput_clf_accuracy: 0.9258 - val_ouput_clf_mse: 392.9654 - val_ouput_reg_accuracy: 0.3503 - val_ouput_reg_mse: 0.1477
# Epoch 22/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.1861 - ouput_clf_loss: 0.1762 - ouput_reg_loss: 0.0099 - ouput_clf_accuracy: 0.9538 - ouput_clf_mse: 395.3167 - ouput_reg_accuracy: 0.4956 - ouput_reg_mse: 0.0099 - val_loss: 0.4585 - val_ouput_clf_loss: 0.4331 - val_ouput_reg_loss: 0.0254 - val_ouput_clf_accuracy: 0.9168 - val_ouput_clf_mse: 392.9660 - val_ouput_reg_accuracy: 0.5954 - val_ouput_reg_mse: 0.0254
# Epoch 23/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.1610 - ouput_clf_loss: 0.1500 - ouput_reg_loss: 0.0110 - ouput_clf_accuracy: 0.9610 - ouput_clf_mse: 394.1356 - ouput_reg_accuracy: 0.5088 - ouput_reg_mse: 0.0110 - val_loss: 0.3778 - val_ouput_clf_loss: 0.3534 - val_ouput_reg_loss: 0.0244 - val_ouput_clf_accuracy: 0.9356 - val_ouput_clf_mse: 392.9663 - val_ouput_reg_accuracy: 0.3865 - val_ouput_reg_mse: 0.0244
# Epoch 24/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.1646 - ouput_clf_loss: 0.1555 - ouput_reg_loss: 0.0092 - ouput_clf_accuracy: 0.9621 - ouput_clf_mse: 393.5284 - ouput_reg_accuracy: 0.4997 - ouput_reg_mse: 0.0092 - val_loss: 0.4726 - val_ouput_clf_loss: 0.4408 - val_ouput_reg_loss: 0.0318 - val_ouput_clf_accuracy: 0.9068 - val_ouput_clf_mse: 392.9653 - val_ouput_reg_accuracy: 0.5171 - val_ouput_reg_mse: 0.0318
# Epoch 25/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.1834 - ouput_clf_loss: 0.1704 - ouput_reg_loss: 0.0130 - ouput_clf_accuracy: 0.9555 - ouput_clf_mse: 397.4115 - ouput_reg_accuracy: 0.5224 - ouput_reg_mse: 0.0130 - val_loss: 0.3789 - val_ouput_clf_loss: 0.3765 - val_ouput_reg_loss: 0.0025 - val_ouput_clf_accuracy: 0.9370 - val_ouput_clf_mse: 392.9664 - val_ouput_reg_accuracy: 0.4636 - val_ouput_reg_mse: 0.0025
# Epoch 26/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.1335 - ouput_clf_loss: 0.1295 - ouput_reg_loss: 0.0041 - ouput_clf_accuracy: 0.9676 - ouput_clf_mse: 393.8930 - ouput_reg_accuracy: 0.5144 - ouput_reg_mse: 0.0041 - val_loss: 0.4246 - val_ouput_clf_loss: 0.3644 - val_ouput_reg_loss: 0.0603 - val_ouput_clf_accuracy: 0.9321 - val_ouput_clf_mse: 392.9659 - val_ouput_reg_accuracy: 0.5931 - val_ouput_reg_mse: 0.0603
# Epoch 27/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.1371 - ouput_clf_loss: 0.1307 - ouput_reg_loss: 0.0064 - ouput_clf_accuracy: 0.9680 - ouput_clf_mse: 395.7243 - ouput_reg_accuracy: 0.5104 - ouput_reg_mse: 0.0064 - val_loss: 0.3717 - val_ouput_clf_loss: 0.3702 - val_ouput_reg_loss: 0.0016 - val_ouput_clf_accuracy: 0.9357 - val_ouput_clf_mse: 392.9666 - val_ouput_reg_accuracy: 0.4528 - val_ouput_reg_mse: 0.0016
# Epoch 28/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.1497 - ouput_clf_loss: 0.1434 - ouput_reg_loss: 0.0063 - ouput_clf_accuracy: 0.9641 - ouput_clf_mse: 392.2867 - ouput_reg_accuracy: 0.5347 - ouput_reg_mse: 0.0063 - val_loss: 0.4751 - val_ouput_clf_loss: 0.4690 - val_ouput_reg_loss: 0.0062 - val_ouput_clf_accuracy: 0.9184 - val_ouput_clf_mse: 392.9665 - val_ouput_reg_accuracy: 0.6138 - val_ouput_reg_mse: 0.0062
# Epoch 29/30
# 490/490 [==============================] - 4s 6ms/step - loss: 0.2654 - ouput_clf_loss: 0.1700 - ouput_reg_loss: 0.0954 - ouput_clf_accuracy: 0.9555 - ouput_clf_mse: 391.0022 - ouput_reg_accuracy: 0.4839 - ouput_reg_mse: 0.0954 - val_loss: 0.4349 - val_ouput_clf_loss: 0.4329 - val_ouput_reg_loss: 0.0020 - val_ouput_clf_accuracy: 0.9226 - val_ouput_clf_mse: 392.9661 - val_ouput_reg_accuracy: 0.4763 - val_ouput_reg_mse: 0.0020
# Epoch 30/30
# 490/490 [==============================] - 4s 7ms/step - loss: 0.1485 - ouput_clf_loss: 0.1466 - ouput_reg_loss: 0.0019 - ouput_clf_accuracy: 0.9642 - ouput_clf_mse: 391.0155 - ouput_reg_accuracy: 0.5078 - ouput_reg_mse: 0.0019 - val_loss: 0.3986 - val_ouput_clf_loss: 0.3971 - val_ouput_reg_loss: 0.0015 - val_ouput_clf_accuracy: 0.9318 - val_ouput_clf_mse: 392.9666 - val_ouput_reg_accuracy: 0.6273 - val_ouput_reg_mse: 0.0015

# %%
#acc      = history.history['accuracy' ]
#val_acc  = history.history['val_accuracy' ]
loss     = history.history['loss' ]
val_loss = history.history['val_loss']

# %%
epochs = range(len(loss))

# plt.plot(epochs, acc, 'r', label='Training accuracy')
# plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
# plt.title('Training and validation accuracy')
# plt.legend()
# plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
clf_acc = history.history['ouput_clf_accuracy']
val_clf_acc = history.history['val_ouput_clf_accuracy']

plt.plot(epochs, clf_acc, 'r', label='Classification acc')
plt.plot(epochs, val_clf_acc, 'b', label='Val Classification acc')
plt.title('Training and validation classification accuracy')
plt.legend()

plt.show()

# %%
box_mse = history.history['ouput_reg_mse']
val_box_mse = history.history['val_ouput_reg_mse']

plt.plot(epochs, box_mse, 'r', label='box acc')
plt.plot(epochs, val_box_mse, 'b', label='Val box acc')
plt.title('Training and validation regression--box accuracy')
plt.legend()

plt.show()
